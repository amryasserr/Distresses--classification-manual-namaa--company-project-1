# %% [markdown]
# ```
# This Program Belongs To Namaa Consult S.A.E. Only
# Made By: Eng. Mohamed Fawzy (01030591128) | Eng. Amr Yasser (01223922540)
# ```

# %% [markdown]
# PART (1) : BLEEDING DISTRESS

# %%
#Importing Some Important Modules And Libraries
import os
import csv
import shutil
import pyodbc
import pandas as pd

# %%
#You Need To Change It To Your Own Path
path = 'C:\\Users\\Mohamed Fawzy\\Documents\\Python Projects\\Namaa Projects\\03-Second Project'

# %%
#To Read An Access File.. You Need To Change It To Your Own Path And File Name
conn = pyodbc.connect(r'Driver={Microsoft Access Driver (*.mdb, *.accdb)};DBQ=C:\\Users\\Mohamed Fawzy\\Documents\\Python Projects\\Namaa Projects\\03-Second Project\\1-2-2022(1).mdb;')

# %%
#To Select A Specific Table From The Access File
cursor = conn.cursor()
cursor.execute('select * from dt_Event_BLEEDING')

#To Make An Empty List
lst_access = []

#To Save All Data Which Founded In The Specific Table In The Access File In A List
for row in cursor.fetchall():
    lst_access.append(row)

#To Show The Content Of The List
lst_access

# %%
#To Create A CSV File Contains The Data Of The Specific Table Which Already Stored In A List
with open ('Event_BLEEDING.csv', 'w', newline='') as f:
    writer = csv.DictWriter(f, fieldnames=['Survey_ID','BLEEDING','Chainage_Start','Chainage_End','Length','LRP_Number_Start','LRP_Offset_Start','LRP_Number_End','LRP_Offset_End','Frame_Start','Frame_End','Comment','Comment_1','Comment_2','Comment_3','Comment_4','Photo_Set','X','Y','Z','X_End','Y_End','Z_End'])
    writer.writeheader()
    
    for t in lst_access:
        Survey_ID = t[0]
        BLEEDING = (t[1])
        Chainage_Start = t[2]
        Chainage_End = (t[3])
        Length = t[4]
        LRP_Number_Start = (t[5])
        LRP_Offset_Start = t[6]
        LRP_Number_End = t[7]
        LRP_Offset_End = t[8]
        Frame_Start = t[9]
        Frame_End = t[10]
        Comment = t[11]
        Comment_1 = t[12]
        Comment_2 = t[13]
        Comment_3 = t[14]
        Comment_4 = t[15]
        Photo_Set = t[16]
        X = t[17]
        Y = t[18]
        Z = t[19]
        X_End = t[20]
        Y_End = t[21]
        Z_End = t[22]

        writer.writerow(
            {
                'Survey_ID' : Survey_ID,
                'BLEEDING' : BLEEDING,
                'Chainage_Start' : Chainage_Start,
                'Chainage_End' : Chainage_End,
                'Length' : Length,
                'LRP_Number_Start' : LRP_Number_Start,
                'LRP_Offset_Start' : LRP_Offset_Start,
                'LRP_Number_End' : LRP_Number_End,
                'LRP_Offset_End' : LRP_Offset_End,
                'Frame_Start' : Frame_Start,
                'Frame_End' : Frame_End,
                'Comment' : Comment,
                'Comment_1' : Comment_1,
                'Comment_2' : Comment_2,
                'Comment_3' : Comment_3,
                'Comment_4' : Comment_4,
                'Photo_Set' : Photo_Set,
                'X' : X,
                'Y' : Y,
                'Z': Z,
                'X_End' : X_End,
                'Y_End' : Y_End,
                'Z_End' : Z_End
            }
        )

# %%
#To Read The CSV File
Event_BLEEDING = pd.read_csv('Event_BLEEDING.csv')

#To Show The Content Of The CSV File
Event_BLEEDING

# %%
#To Save All Rows Values Of (Survey_ID) Column Which Founded In The CSV File In A Variable
Survey_ID = Event_BLEEDING["Survey_ID"]

#To Show The Content Of The Variable
Survey_ID

# %%
#To Make An Empty List
lst_survey = []

#To Save All Streets Numbers Which Founded In Access File In (Survey_ID) Column In A List
for s in Survey_ID:
    lst_survey.append(s)

#To Remove The Duplicate Of Streets Numbers By Converting The List To Set
lst_survey = set(lst_survey)

#To Convert The Set To List Again
lst_survey = list(lst_survey)

#To Show The Content Of The List
lst_survey

# %%
#To Make An Empty List
lst_final = []

#To Save The Existing Streets Numbers Which Founded In Both (Access File & Operating System) In A List
for o in lst_survey:
    if o in os.listdir(path):
        lst_final.append(o)

#To Show The Content Of The List
lst_final

# %%
#To Define A Function That Makes Some Operations In Operating System
def get_street_imgs(path):
    for m in lst_final:
        out_street = os.listdir(f"{m}\Romdas360")
        src_dir = (f"{m}\Romdas360")


        for j in Event_BLEEDING.iloc:
            
            lst_bleeding = []

            if j["Comment_1"] == "LOW":
                dst_dir = "Bleeding\LOW"
                FS = int(j['Frame_Start'])
                FE = int(j['Frame_End']) + 1

                for k in range (FS,FE):
                    if len(str(k)) == 1:
                        df = j["Survey_ID"] + f"-Romdas360-0-0000{k}.jpg"
                        lst_bleeding.append(df)
                    elif len(str(k)) == 2:
                        df = j["Survey_ID"] + f"-Romdas360-0-000{k}.jpg"
                        lst_bleeding.append(df)
                    elif len(str(k)) == 3:
                        df = j["Survey_ID"] + f"-Romdas360-0-00{k}.jpg"
                        lst_bleeding.append(df)
                    elif len(str(k)) == 4:
                        df = j["Survey_ID"] + f"-Romdas360-0-0{k}.jpg"
                        lst_bleeding.append(df)
                    elif len(str(k)) == 5:
                        df = j["Survey_ID"] + f"-Romdas360-0-{k}.jpg"
                        lst_bleeding.append(df)
                for f in lst_bleeding:
                    if f in out_street:
                        shutil.copy(src_dir+"\\"+f,dst_dir+"\\"+f)
            
            elif j["Comment_1"] == "MED":
                dst_dir = "Bleeding\MED"
                FS = int(j['Frame_Start'])
                FE = int(j['Frame_End']) + 1
                for k in range (FS,FE):
                    if len(str(k)) == 1:
                        df = j["Survey_ID"] + f"-Romdas360-0-0000{k}.jpg"
                        lst_bleeding.append(df)
                    elif len(str(k)) == 2:
                        df = j["Survey_ID"] + f"-Romdas360-0-000{k}.jpg"
                        lst_bleeding.append(df)
                    elif len(str(k)) == 3:
                        df = j["Survey_ID"] + f"-Romdas360-0-00{k}.jpg"
                        lst_bleeding.append(df)
                    elif len(str(k)) == 4:
                        df = j["Survey_ID"] + f"-Romdas360-0-0{k}.jpg"
                        lst_bleeding.append(df)
                    elif len(str(k)) == 5:
                        df = j["Survey_ID"] + f"-Romdas360-0-{k}.jpg"
                        lst_bleeding.append(df)
                for f in lst_bleeding:
                    if f in out_street:
                        shutil.copy(src_dir+"\\"+f,dst_dir+"\\"+f)
            
            elif j["Comment_1"] == "HIGH":
                dst_dir = "Bleeding\HIGH"
                FS = int(j['Frame_Start'])
                FE = int(j['Frame_End']) + 1
                for k in range (FS,FE):
                    if len(str(k)) == 1:
                        df = j["Survey_ID"] + f"-Romdas360-0-0000{k}.jpg"
                        lst_bleeding.append(df)
                    elif len(str(k)) == 2:
                        df = j["Survey_ID"] + f"-Romdas360-0-000{k}.jpg"
                        lst_bleeding.append(df)
                    elif len(str(k)) == 3:
                        df = j["Survey_ID"] + f"-Romdas360-0-00{k}.jpg"
                        lst_bleeding.append(df)
                    elif len(str(k)) == 4:
                        df = j["Survey_ID"] + f"-Romdas360-0-0{k}.jpg"
                        lst_bleeding.append(df)
                    elif len(str(k)) == 5:
                        df = j["Survey_ID"] + f"-Romdas360-0-{k}.jpg"
                        lst_bleeding.append(df)
                for f in lst_bleeding:
                    if f in out_street:
                        shutil.copy(src_dir+"\\"+f,dst_dir+"\\"+f)

# %%
#To Apply The Function Which We Just Defined It
get_street_imgs(path)

# %% [markdown]
# PART (2) : PATCHING DISTRESS

# %%
#To Select A Specific Table From The Access File
cursor = conn.cursor()
cursor.execute('select * from dt_Event_PATCHING_AREA')

#To Make An Empty List
lst_access = []

#To Save All Data Which Founded In The Specific Table In The Access File In A List
for row in cursor.fetchall():
    lst_access.append(row)

#To Show The Content Of The List
lst_access

# %%
#To Create A CSV File Contains The Data Of The Specific Table Which Already Stored In A List
with open ('Event_PATCHING_AREA.csv', 'w', newline='') as f:
    writer = csv.DictWriter(f, fieldnames=['Survey_ID','PATCHING_AREA','Chainage_Start','Chainage_End','Length','LRP_Number_Start','LRP_Offset_Start','LRP_Number_End','LRP_Offset_End','Frame_Start','Frame_End','Comment','Comment_1','Comment_2','Comment_3','Comment_4','Photo_Set','X','Y','Z','X_End','Y_End','Z_End'])
    writer.writeheader()
    
    for t in lst_access:
        Survey_ID = t[0]
        PATCHING_AREA = (t[1])
        Chainage_Start = t[2]
        Chainage_End = (t[3])
        Length = t[4]
        LRP_Number_Start = (t[5])
        LRP_Offset_Start = t[6]
        LRP_Number_End = t[7]
        LRP_Offset_End = t[8]
        Frame_Start = t[9]
        Frame_End = t[10]
        Comment = t[11]
        Comment_1 = t[12]
        Comment_2 = t[13]
        Comment_3 = t[14]
        Comment_4 = t[15]
        Photo_Set = t[16]
        X = t[17]
        Y = t[18]
        Z = t[19]
        X_End = t[20]
        Y_End = t[21]
        Z_End = t[22]

        writer.writerow(
            {
                'Survey_ID' : Survey_ID,
                'PATCHING_AREA' : PATCHING_AREA,
                'Chainage_Start' : Chainage_Start,
                'Chainage_End' : Chainage_End,
                'Length' : Length,
                'LRP_Number_Start' : LRP_Number_Start,
                'LRP_Offset_Start' : LRP_Offset_Start,
                'LRP_Number_End' : LRP_Number_End,
                'LRP_Offset_End' : LRP_Offset_End,
                'Frame_Start' : Frame_Start,
                'Frame_End' : Frame_End,
                'Comment' : Comment,
                'Comment_1' : Comment_1,
                'Comment_2' : Comment_2,
                'Comment_3' : Comment_3,
                'Comment_4' : Comment_4,
                'Photo_Set' : Photo_Set,
                'X' : X,
                'Y' : Y,
                'Z': Z,
                'X_End' : X_End,
                'Y_End' : Y_End,
                'Z_End' : Z_End
            }
        )

# %%
#To Read The CSV File
Event_PATCHING_AREA = pd.read_csv('Event_PATCHING_AREA.csv')

#To Show The Content Of The CSV File
Event_PATCHING_AREA

# %%
#To Save All Rows Values Of (Survey_ID) Column Which Founded In The CSV File In A Variable
Survey_ID = Event_PATCHING_AREA["Survey_ID"]

#To Show The Content Of The Variable
Survey_ID

# %%
#To Make An Empty List
lst_survey = []

#To Save All Streets Numbers Which Founded In Access File In (Survey_ID) Column In A List
for s in Survey_ID:
    lst_survey.append(s)

#To Remove The Duplicate Of Streets Numbers By Converting The List To Set
lst_survey = set(lst_survey)

#To Convert The Set To List Again
lst_survey = list(lst_survey)

#To Show The Content Of The List
lst_survey

# %%
#To Make An Empty List
lst_final = []

#To Save The Existing Streets Numbers Which Founded In Both (Access File & Operating System) In A List
for o in lst_survey:
    if o in os.listdir(path):
        lst_final.append(o)

#To Show The Content Of The List
lst_final

# %%
#To Define A Function That Makes Some Operations In Operating System
def get_street_imgs(path):
    for m in lst_final:
        out_street = os.listdir(f"{m}\Romdas360")
        src_dir = (f"{m}\Romdas360")


        for j in Event_PATCHING_AREA.iloc:
            
            lst_patching = []

            if j["Comment_1"] == "LOW":
                dst_dir = "Patching\LOW"
                FS = int(j['Frame_Start'])
                FE = int(j['Frame_End']) + 1

                for k in range (FS,FE):
                    if len(str(k)) == 1:
                        df = j["Survey_ID"] + f"-Romdas360-0-0000{k}.jpg"
                        lst_patching.append(df)
                    elif len(str(k)) == 2:
                        df = j["Survey_ID"] + f"-Romdas360-0-000{k}.jpg"
                        lst_patching.append(df)
                    elif len(str(k)) == 3:
                        df = j["Survey_ID"] + f"-Romdas360-0-00{k}.jpg"
                        lst_patching.append(df)
                    elif len(str(k)) == 4:
                        df = j["Survey_ID"] + f"-Romdas360-0-0{k}.jpg"
                        lst_patching.append(df)
                    elif len(str(k)) == 5:
                        df = j["Survey_ID"] + f"-Romdas360-0-{k}.jpg"
                        lst_patching.append(df)
                for f in lst_patching:
                    if f in out_street:
                        shutil.copy(src_dir+"\\"+f,dst_dir+"\\"+f)
            
            elif j["Comment_1"] == "MED":
                dst_dir = "Patching\MED"
                FS = int(j['Frame_Start'])
                FE = int(j['Frame_End']) + 1
                for k in range (FS,FE):
                    if len(str(k)) == 1:
                        df = j["Survey_ID"] + f"-Romdas360-0-0000{k}.jpg"
                        lst_patching.append(df)
                    elif len(str(k)) == 2:
                        df = j["Survey_ID"] + f"-Romdas360-0-000{k}.jpg"
                        lst_patching.append(df)
                    elif len(str(k)) == 3:
                        df = j["Survey_ID"] + f"-Romdas360-0-00{k}.jpg"
                        lst_patching.append(df)
                    elif len(str(k)) == 4:
                        df = j["Survey_ID"] + f"-Romdas360-0-0{k}.jpg"
                        lst_patching.append(df)
                    elif len(str(k)) == 5:
                        df = j["Survey_ID"] + f"-Romdas360-0-{k}.jpg"
                        lst_patching.append(df)
                for f in lst_patching:
                    if f in out_street:
                        shutil.copy(src_dir+"\\"+f,dst_dir+"\\"+f)
            
            elif j["Comment_1"] == "HIGH":
                dst_dir = "Patching\HIGH"
                FS = int(j['Frame_Start'])
                FE = int(j['Frame_End']) + 1
                for k in range (FS,FE):
                    if len(str(k)) == 1:
                        df = j["Survey_ID"] + f"-Romdas360-0-0000{k}.jpg"
                        lst_patching.append(df)
                    elif len(str(k)) == 2:
                        df = j["Survey_ID"] + f"-Romdas360-0-000{k}.jpg"
                        lst_patching.append(df)
                    elif len(str(k)) == 3:
                        df = j["Survey_ID"] + f"-Romdas360-0-00{k}.jpg"
                        lst_patching.append(df)
                    elif len(str(k)) == 4:
                        df = j["Survey_ID"] + f"-Romdas360-0-0{k}.jpg"
                        lst_patching.append(df)
                    elif len(str(k)) == 5:
                        df = j["Survey_ID"] + f"-Romdas360-0-{k}.jpg"
                        lst_patching.append(df)
                for f in lst_patching:
                    if f in out_street:
                        shutil.copy(src_dir+"\\"+f,dst_dir+"\\"+f)

# %%
#To Apply The Function Which We Just Defined It
get_street_imgs(path)

# %% [markdown]
# PART (3) : RAVELLING DISTRESS

# %%
#To Select A Specific Table From The Access File
cursor = conn.cursor()
cursor.execute('select * from dt_Event_RAVELLING_AREA')

#To Make An Empty List
lst_access = []

#To Save All Data Which Founded In The Specific Table In The Access File In A List
for row in cursor.fetchall():
    lst_access.append(row)

#To Show The Content Of The List
lst_access

# %%
#To Create A CSV File Contains The Data Of The Specific Table Which Already Stored In A List
with open ('Event_RAVELLING_AREA.csv', 'w', newline='') as f:
    writer = csv.DictWriter(f, fieldnames=['Survey_ID','RAVELLING_AREA','Chainage_Start','Chainage_End','Length','LRP_Number_Start','LRP_Offset_Start','LRP_Number_End','LRP_Offset_End','Frame_Start','Frame_End','Comment','Comment_1','Comment_2','Comment_3','Comment_4','Photo_Set','X','Y','Z','X_End','Y_End','Z_End'])
    writer.writeheader()
    
    for t in lst_access:
        Survey_ID = t[0]
        RAVELLING_AREA = (t[1])
        Chainage_Start = t[2]
        Chainage_End = (t[3])
        Length = t[4]
        LRP_Number_Start = (t[5])
        LRP_Offset_Start = t[6]
        LRP_Number_End = t[7]
        LRP_Offset_End = t[8]
        Frame_Start = t[9]
        Frame_End = t[10]
        Comment = t[11]
        Comment_1 = t[12]
        Comment_2 = t[13]
        Comment_3 = t[14]
        Comment_4 = t[15]
        Photo_Set = t[16]
        X = t[17]
        Y = t[18]
        Z = t[19]
        X_End = t[20]
        Y_End = t[21]
        Z_End = t[22]

        writer.writerow(
            {
                'Survey_ID' : Survey_ID,
                'RAVELLING_AREA' : RAVELLING_AREA,
                'Chainage_Start' : Chainage_Start,
                'Chainage_End' : Chainage_End,
                'Length' : Length,
                'LRP_Number_Start' : LRP_Number_Start,
                'LRP_Offset_Start' : LRP_Offset_Start,
                'LRP_Number_End' : LRP_Number_End,
                'LRP_Offset_End' : LRP_Offset_End,
                'Frame_Start' : Frame_Start,
                'Frame_End' : Frame_End,
                'Comment' : Comment,
                'Comment_1' : Comment_1,
                'Comment_2' : Comment_2,
                'Comment_3' : Comment_3,
                'Comment_4' : Comment_4,
                'Photo_Set' : Photo_Set,
                'X' : X,
                'Y' : Y,
                'Z': Z,
                'X_End' : X_End,
                'Y_End' : Y_End,
                'Z_End' : Z_End
            }
        )

# %%
#To Read The CSV File
Event_RAVELLING_AREA = pd.read_csv('Event_RAVELLING_AREA.csv')

#To Show The Content Of The CSV File
Event_RAVELLING_AREA

# %%
#To Save All Rows Values Of (Survey_ID) Column Which Founded In The CSV File In A Variable
Survey_ID = Event_RAVELLING_AREA["Survey_ID"]

#To Show The Content Of The Variable
Survey_ID

# %%
#To Make An Empty List
lst_survey = []

#To Save All Streets Numbers Which Founded In Access File In (Survey_ID) Column In A List
for s in Survey_ID:
    lst_survey.append(s)

#To Remove The Duplicate Of Streets Numbers By Converting The List To Set
lst_survey = set(lst_survey)

#To Convert The Set To List Again
lst_survey = list(lst_survey)

#To Show The Content Of The List
lst_survey

# %%
#To Make An Empty List
lst_final = []

#To Save The Existing Streets Numbers Which Founded In Both (Access File & Operating System) In A List
for o in lst_survey:
    if o in os.listdir(path):
        lst_final.append(o)

#To Show The Content Of The List
lst_final

# %%
#To Define A Function That Makes Some Operations In Operating System
def get_street_imgs(path):
    for m in lst_final:
        out_street = os.listdir(f"{m}\Romdas360")
        src_dir = (f"{m}\Romdas360")


        for j in Event_RAVELLING_AREA.iloc:
            
            lst_ravelling = []

            if j["Comment_1"] == "LOW":
                dst_dir = "Ravelling\LOW"
                FS = int(j['Frame_Start'])
                FE = int(j['Frame_End']) + 1

                for k in range (FS,FE):
                    if len(str(k)) == 1:
                        df = j["Survey_ID"] + f"-Romdas360-0-0000{k}.jpg"
                        lst_ravelling.append(df)
                    elif len(str(k)) == 2:
                        df = j["Survey_ID"] + f"-Romdas360-0-000{k}.jpg"
                        lst_ravelling.append(df)
                    elif len(str(k)) == 3:
                        df = j["Survey_ID"] + f"-Romdas360-0-00{k}.jpg"
                        lst_ravelling.append(df)
                    elif len(str(k)) == 4:
                        df = j["Survey_ID"] + f"-Romdas360-0-0{k}.jpg"
                        lst_ravelling.append(df)
                    elif len(str(k)) == 5:
                        df = j["Survey_ID"] + f"-Romdas360-0-{k}.jpg"
                        lst_ravelling.append(df)
                for f in lst_ravelling:
                    if f in out_street:
                        shutil.copy(src_dir+"\\"+f,dst_dir+"\\"+f)
            
            elif j["Comment_1"] == "MED":
                dst_dir = "Ravelling\MED"
                FS = int(j['Frame_Start'])
                FE = int(j['Frame_End']) + 1
                for k in range (FS,FE):
                    if len(str(k)) == 1:
                        df = j["Survey_ID"] + f"-Romdas360-0-0000{k}.jpg"
                        lst_ravelling.append(df)
                    elif len(str(k)) == 2:
                        df = j["Survey_ID"] + f"-Romdas360-0-000{k}.jpg"
                        lst_ravelling.append(df)
                    elif len(str(k)) == 3:
                        df = j["Survey_ID"] + f"-Romdas360-0-00{k}.jpg"
                        lst_ravelling.append(df)
                    elif len(str(k)) == 4:
                        df = j["Survey_ID"] + f"-Romdas360-0-0{k}.jpg"
                        lst_ravelling.append(df)
                    elif len(str(k)) == 5:
                        df = j["Survey_ID"] + f"-Romdas360-0-{k}.jpg"
                        lst_ravelling.append(df)
                for f in lst_ravelling:
                    if f in out_street:
                        shutil.copy(src_dir+"\\"+f,dst_dir+"\\"+f)
            
            elif j["Comment_1"] == "HIGH":
                dst_dir = "Ravelling\HIGH"
                FS = int(j['Frame_Start'])
                FE = int(j['Frame_End']) + 1
                for k in range (FS,FE):
                    if len(str(k)) == 1:
                        df = j["Survey_ID"] + f"-Romdas360-0-0000{k}.jpg"
                        lst_ravelling.append(df)
                    elif len(str(k)) == 2:
                        df = j["Survey_ID"] + f"-Romdas360-0-000{k}.jpg"
                        lst_ravelling.append(df)
                    elif len(str(k)) == 3:
                        df = j["Survey_ID"] + f"-Romdas360-0-00{k}.jpg"
                        lst_ravelling.append(df)
                    elif len(str(k)) == 4:
                        df = j["Survey_ID"] + f"-Romdas360-0-0{k}.jpg"
                        lst_ravelling.append(df)
                    elif len(str(k)) == 5:
                        df = j["Survey_ID"] + f"-Romdas360-0-{k}.jpg"
                        lst_ravelling.append(df)
                for f in lst_ravelling:
                    if f in out_street:
                        shutil.copy(src_dir+"\\"+f,dst_dir+"\\"+f)

# %%
#To Apply The Function Which We Just Defined It
get_street_imgs(path)

# %% [markdown]
# PART (4) : SHOVING DISTRESS

# %%
#To Select A Specific Table From The Access File
cursor = conn.cursor()
cursor.execute('select * from dt_Event_SHOVING_AREA')

#To Make An Empty List
lst_access = []

#To Save All Data Which Founded In The Specific Table In The Access File In A List
for row in cursor.fetchall():
    lst_access.append(row)

#To Show The Content Of The List
lst_access

# %%
#To Create A CSV File Contains The Data Of The Specific Table Which Already Stored In A List
with open ('Event_SHOVING_AREA.csv', 'w', newline='') as f:
    writer = csv.DictWriter(f, fieldnames=['Survey_ID','SHOVING_AREA','Chainage_Start','Chainage_End','Length','LRP_Number_Start','LRP_Offset_Start','LRP_Number_End','LRP_Offset_End','Frame_Start','Frame_End','Comment','Comment_1','Comment_2','Comment_3','Comment_4','Photo_Set','X','Y','Z','X_End','Y_End','Z_End'])
    writer.writeheader()
    
    for t in lst_access:
        Survey_ID = t[0]
        SHOVING_AREA = (t[1])
        Chainage_Start = t[2]
        Chainage_End = (t[3])
        Length = t[4]
        LRP_Number_Start = (t[5])
        LRP_Offset_Start = t[6]
        LRP_Number_End = t[7]
        LRP_Offset_End = t[8]
        Frame_Start = t[9]
        Frame_End = t[10]
        Comment = t[11]
        Comment_1 = t[12]
        Comment_2 = t[13]
        Comment_3 = t[14]
        Comment_4 = t[15]
        Photo_Set = t[16]
        X = t[17]
        Y = t[18]
        Z = t[19]
        X_End = t[20]
        Y_End = t[21]
        Z_End = t[22]

        writer.writerow(
            {
                'Survey_ID' : Survey_ID,
                'SHOVING_AREA' : SHOVING_AREA,
                'Chainage_Start' : Chainage_Start,
                'Chainage_End' : Chainage_End,
                'Length' : Length,
                'LRP_Number_Start' : LRP_Number_Start,
                'LRP_Offset_Start' : LRP_Offset_Start,
                'LRP_Number_End' : LRP_Number_End,
                'LRP_Offset_End' : LRP_Offset_End,
                'Frame_Start' : Frame_Start,
                'Frame_End' : Frame_End,
                'Comment' : Comment,
                'Comment_1' : Comment_1,
                'Comment_2' : Comment_2,
                'Comment_3' : Comment_3,
                'Comment_4' : Comment_4,
                'Photo_Set' : Photo_Set,
                'X' : X,
                'Y' : Y,
                'Z': Z,
                'X_End' : X_End,
                'Y_End' : Y_End,
                'Z_End' : Z_End
            }
        )

# %%
#To Read The CSV File
Event_SHOVING_AREA = pd.read_csv('Event_SHOVING_AREA.csv')

#To Show The Content Of The CSV File
Event_SHOVING_AREA

# %%
#To Save All Rows Values Of (Survey_ID) Column Which Founded In The CSV File In A Variable
Survey_ID = Event_SHOVING_AREA["Survey_ID"]

#To Show The Content Of The Variable
Survey_ID

# %%
#To Make An Empty List
lst_survey = []

#To Save All Streets Numbers Which Founded In Access File In (Survey_ID) Column In A List
for s in Survey_ID:
    lst_survey.append(s)

#To Remove The Duplicate Of Streets Numbers By Converting The List To Set
lst_survey = set(lst_survey)

#To Convert The Set To List Again
lst_survey = list(lst_survey)

#To Show The Content Of The List
lst_survey

# %%
#To Make An Empty List
lst_final = []

#To Save The Existing Streets Numbers Which Founded In Both (Access File & Operating System) In A List
for o in lst_survey:
    if o in os.listdir(path):
        lst_final.append(o)

#To Show The Content Of The List
lst_final

# %%
#To Define A Function That Makes Some Operations In Operating System
def get_street_imgs(path):
    for m in lst_final:
        out_street = os.listdir(f"{m}\Romdas360")
        src_dir = (f"{m}\Romdas360")


        for j in Event_SHOVING_AREA.iloc:
            
            lst_shoving = []

            if j["Comment_1"] == "LOW":
                dst_dir = "Shoving\LOW"
                FS = int(j['Frame_Start'])
                FE = int(j['Frame_End']) + 1

                for k in range (FS,FE):
                    if len(str(k)) == 1:
                        df = j["Survey_ID"] + f"-Romdas360-0-0000{k}.jpg"
                        lst_shoving.append(df)
                    elif len(str(k)) == 2:
                        df = j["Survey_ID"] + f"-Romdas360-0-000{k}.jpg"
                        lst_shoving.append(df)
                    elif len(str(k)) == 3:
                        df = j["Survey_ID"] + f"-Romdas360-0-00{k}.jpg"
                        lst_shoving.append(df)
                    elif len(str(k)) == 4:
                        df = j["Survey_ID"] + f"-Romdas360-0-0{k}.jpg"
                        lst_shoving.append(df)
                    elif len(str(k)) == 5:
                        df = j["Survey_ID"] + f"-Romdas360-0-{k}.jpg"
                        lst_shoving.append(df)
                for f in lst_shoving:
                    if f in out_street:
                        shutil.copy(src_dir+"\\"+f,dst_dir+"\\"+f)
            
            elif j["Comment_1"] == "MED":
                dst_dir = "Shoving\MED"
                FS = int(j['Frame_Start'])
                FE = int(j['Frame_End']) + 1
                for k in range (FS,FE):
                    if len(str(k)) == 1:
                        df = j["Survey_ID"] + f"-Romdas360-0-0000{k}.jpg"
                        lst_shoving.append(df)
                    elif len(str(k)) == 2:
                        df = j["Survey_ID"] + f"-Romdas360-0-000{k}.jpg"
                        lst_shoving.append(df)
                    elif len(str(k)) == 3:
                        df = j["Survey_ID"] + f"-Romdas360-0-00{k}.jpg"
                        lst_shoving.append(df)
                    elif len(str(k)) == 4:
                        df = j["Survey_ID"] + f"-Romdas360-0-0{k}.jpg"
                        lst_shoving.append(df)
                    elif len(str(k)) == 5:
                        df = j["Survey_ID"] + f"-Romdas360-0-{k}.jpg"
                        lst_shoving.append(df)
                for f in lst_shoving:
                    if f in out_street:
                        shutil.copy(src_dir+"\\"+f,dst_dir+"\\"+f)
            
            elif j["Comment_1"] == "HIGH":
                dst_dir = "Shoving\HIGH"
                FS = int(j['Frame_Start'])
                FE = int(j['Frame_End']) + 1
                for k in range (FS,FE):
                    if len(str(k)) == 1:
                        df = j["Survey_ID"] + f"-Romdas360-0-0000{k}.jpg"
                        lst_shoving.append(df)
                    elif len(str(k)) == 2:
                        df = j["Survey_ID"] + f"-Romdas360-0-000{k}.jpg"
                        lst_shoving.append(df)
                    elif len(str(k)) == 3:
                        df = j["Survey_ID"] + f"-Romdas360-0-00{k}.jpg"
                        lst_shoving.append(df)
                    elif len(str(k)) == 4:
                        df = j["Survey_ID"] + f"-Romdas360-0-0{k}.jpg"
                        lst_shoving.append(df)
                    elif len(str(k)) == 5:
                        df = j["Survey_ID"] + f"-Romdas360-0-{k}.jpg"
                        lst_shoving.append(df)
                for f in lst_shoving:
                    if f in out_street:
                        shutil.copy(src_dir+"\\"+f,dst_dir+"\\"+f)

# %%
#To Apply The Function Which We Just Defined It
get_street_imgs(path)
